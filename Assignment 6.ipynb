# %% [markdown]
# Q.1. What are keywords in python? Using the keyword library, print all the python keywords.
#
# Ans:Keywords are the reserved words in Python. We cannot use a keyword as a variable name, function name or any other identifier.To get a list of all Python keywords first import the keyword module and use the keyword.kwlist function to get the list of all Python keywords.

# %% [markdown]
# Q.2. What are the rules to create variables in python?
#
# Ans: A Python variable name must start with a letter or the underscore character.
#      A Python variable name cannot start with a number.
#      A Python variable name can only contain alpha-numeric characters and underscores(A-z, 0-9, and _)
#      Variable in Python names are case-sensitive (name, Name, and NAME are three different variables).
#      The reserved words(keywords) in Python cannot be used to name the variable in Python.

# %% [markdown]
# Q.3. What are the standards and conventions followed for the nomenclature of variables in
# python to improve code readability and maintainability?
#
# Ans: A variable name must start with a letter or the underscore character. A variable name cannot start with a number. A variable name can only contain alpha-numeric characters and underscores (A-z, 0-9, and _ ) Variable names are case-sensitive (age, Age and AGE are three different variables).
#
#    Putting Constants Together With Related Code.
#    Creating a Dedicated Module for Constants.
#    Storing Constants in Configuration Files.
#    Handling Constants as Environment Variables.

# %% [markdown]
# Q.4. What will happen if a keyword is used as a variable name?
#
# Ans: We cannot use a keyword as a variable name, function name, or any other identifier. They are used to define the syntax and structure of the Python language.

# %% [markdown]
# Q.5. For what purpose def keyword is used?
#
# Ans: Python def keyword is used to define a function, it is placed before a function name that is provided by the user to create a user-defined function.

# %% [markdown]
# Q.6. What is the operation of this special character ‘\’?
#
# Ans: In Python strings, the backslash "\" is a special character, also called the "escape" character.

# %%
Q.7. Give an example of the following conditions:
(i) Homogeneous list
(ii) Heterogeneous set
(iii) Homogeneous tuple

# %% [markdown]
# Ans: homogeneous_list = [1,2,3,4,5] A homogeneous list in python is a list that contains elements of        the same data type.
#      heterogeneous_set = {1,"apple",3.45,True} A heterogeneous set by including elements of different     data type.
#     Homogeneous_tuple =("apple","banana","cherry","date") in python ,a tuple is an ordered collection     of elements,and it can containelements of different data types.however a homogeneous tuple would       contain elements of the same data type.

# %% [markdown]
# Q.8. Explain the mutable and immutable data types with proper explanation & examples.
#
# Ans:  List, Sets, and Dictionary in Python are examples of some mutable data types in Python.               Immutable data types are those, whose values cannot be modified once they are created. Examples       of immutable data types are int, str, bool, float, tuple, etc.

# %%
Q.9. Write a code to create the given structure using only for loop.
*
***
*****
*******
*********

# %%
for i in range(1,6):
    print('*'*(2*i-1))
# Out:
# *
# ***
# *****
# *******
# *********

# %%
Q.10. Write a code to create the given structure using while loop.
|||||||||
|||||||
|||||
|||
|

# %%
n=5 # Numberof rows

while n > 0:
    print('|' * (2 * n - 1))
    n -= 1
# Out:
# |||||||||
# |||||||
# |||||
# |||
# |
