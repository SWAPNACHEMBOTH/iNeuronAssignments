# %% [markdown]
# 1. In the below elements which of them are values or an expression? eg:- values can be integer or string and expressions will be mathematical operators.
# *
# 'hello'
# -87.8
# -
# /
#
# 6

# %% [markdown]
# Ans :  Expressions : *,-,/
#       Values      :'hello',-87.8,6

# %% [markdown]
#  2. What is the difference between string and variable?

# %% [markdown]
# Ans : A Variable is a store of information and a String is a type of information that would store in a Variable.
#      Variables in programs are references to values that have types. String is simply one of the handful of types that       Python uses along with various number types, collection types.

# %% [markdown]
# 3. Describe three different data types.

# %% [markdown]
#  Ans : Integers, floating point numbers, and complex numbers.

# %% [markdown]
# 4. What is an expression made up of? What do all expressions do?

# %% [markdown]
# Ans : An expression is a combination of values, variables, operators, and calls to function.All expressions evaluate to a single value.

# %% [markdown]
# 5. This assignment statements, like spam = 10. What is the difference between an expression and a statement?

# %% [markdown]
# Ans :Expression is a combination of variables, operations, and values.
#
#    Statements represent an action or command

# %% [markdown]
# 6. After running the following code, what does the variable bacon contain?
# bacon = 22
# bacon + 1

# %% [markdown]
# Ans : bacon =23

# %% [markdown]
# 7. What should the values of the following two terms be?
# 'spam' + 'spamspam'
# 'spam' * 3

# %% [markdown]
# Ans : 'spamspamspam'

# %% [markdown]
# 8. Why is eggs a valid variable name while 100 is invalid?

# %% [markdown]
# Ans : eggs can be used as a variable,but 100 is an integer.

# %% [markdown]
# 9. What three functions can be used to get the integer, floating-point number, or string version of a value?

# %% [markdown]
# Ans :Integer = int()
#      Floating =float()
#     String   =   str()

# %% [markdown]
# 10. Why does this expression cause an error? How can you fix?
#     ‘I have eaten ‘ + 99 + ‘burritos.’

# %% [markdown]
# 'I have eaten + 99 +  burritos'

# %% [markdown]
#  Ans :“99” is an integer and not a string, so the operations are incompatible until “99” is converted into a string.
#
#       use str() to convert “99” to a string.
